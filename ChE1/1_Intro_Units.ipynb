# %% [markdown]
# ## 1. 化学工学とは ##
#
# 化学はもとより、数学、物理・生物学などの基礎知識を工業生産に応用し, **原料から有用な製品を効率的かつ安全に製造するための学問** です。
# 　職業としては、 化学製品を作るための工場や設備（化学プラントといいます）を設計するプラントエンジニア、**化学プラント** において、製造条件,コストなどを勘案して化学プロセスを最適化するプロセスエンジニアなどがあります。皆さんの先輩は国内外で活躍しています。

# %% [markdown]
# <figure style="text-align:center;">
# <img
# src="https://raw.githubusercontent.com/myokota812/lecture/master/ChE1/figures/aspirinPFD.png"
# width="600">
# <figcaption>
# 図1 アスピリン製造プロセスのPFD概略
# </figcaption>
# </figure>

# %% [markdown]
# <details>
# <summary>説明文(ここをクリックして）</summary>
# 化学プロセスの一例を見てみましょう。解熱鎮痛薬のアセチルサリチル酸（アスピリン）の製造プロセスのプロセスフローダイアグラム（PFD)を図１に示します。
# 　皆さんがビーカースケールで目的物質を合成をするときには大まかに
# ~~~
# 反応試薬の調整→混合 → 反応 → 分離・生成 →目的物質
# ~~~
# のフローになると思います。化学プラントでも、その流れは同じです。しかし、大量生産が必要な場合はスケールアップをして、製造する必要があります。そのため、化学プラントではひとつひとつの装置が大きくなっております。さらに、規模が大きいので、装置間の運搬は、すべてポンプを備えた配管を通じて行われます。
# 図１ではどのような装置があるのか各自でよくみてください。
#
# 化学工学では、単に化学反応そのものを扱うだけでなく、以下のような現象や装置設計を対象とします。
#
# 物質移動（蒸留、吸収、抽出、乾燥など）
# 熱移動（加熱、冷却、熱交換器の設計）
# 反応工学（反応器の設計・運転）
# 流体工学（配管やポンプ内の流れ）
# プロセス設計・制御（プラント全体の最適化）
# 環境・エネルギー工学（排水処理、省エネルギー、CO₂削減など）
#
# 化学工学の特徴は、特定の化学物質や製品に限定されず、「物質・エネルギー・情報の流れ」を共通原理として扱う点にあります。そのため、化学産業だけでなく、石油・食品・医薬品・半導体・電池・環境分野など幅広い産業で活用されています。
#
# 化学工学の目的は、製品を大量に、安全に、低コストで、環境負荷を抑えながら生産することにあります。
#
# それでは、化学工学の基礎を勉強していきましょう。

# %% [markdown]
# ***
# ## 2.物理量と単位 ##
# ### 物理量： 長さ、質量、時間、… ###
# ### 物理量の表し方： 数値 $\times$単位 ###

# %% [markdown]
# <details>
# <summary>[説明文]</summary>
# すでに高校や教養課程の物理の授業や基礎物理化学の授業で習った人が多いと思いますが、私たちが物質の特性を比較して論ずるとき、共通の物差しが必要になります。ここでいう共通の物差しを単位と言います。
# 例えば質量を表したいとき、基準になる物差しとして、私たちはキログラム原器というものを用いていました。私たちが物質の質量を議論するとき、私たちはその物質の質量を、1kgの定義の何倍であるかで表現します。このように、全ての物理量には単位があり、基準となる量の何倍という形で表現されます。
# すなわち、物理量は単位と数から成り立ちます。例外として、比重や分子量を挙げることができます。これらはいずれも相対値で無次元です。物理量そのものではなく、二つの物理量の比ということです。
# </details>

# %%
#@title 図２:グラフ上の物理量の表し方（その１）
import matplotlib.pyplot as plt

# 図の作成
fig, ax = plt.subplots(figsize=(4, 4))

# 軸範囲
ax.set_xlim(0, 5)
ax.set_ylim(0, 5)

# 枠線の色
for spine in ax.spines.values():
    spine.set_color('steelblue')
    spine.set_linewidth(2.0)

# x軸目盛り
ax.set_xticks(range(6))
ax.tick_params(
    axis='x',
    direction='in',
    length=12,
    width=1.2,
    colors='cornflowerblue',
    labelsize=28,
    pad=15
)

# y軸目盛りを消す
ax.set_yticks([])

# ラベルを手動配置
ax.text(
    0.18, -0.25,
    'mass, ',
    transform=ax.transAxes,
    fontsize=28,
    color='limegreen',
    ha='left',
    va='top'
)

ax.text(
    0.55, -0.25,
    r'$m$',
    transform=ax.transAxes,
    fontsize=28,
    color='limegreen',
    ha='left',
    va='top'
)

ax.text(
    0.68, -0.25,
    '/kg',
    transform=ax.transAxes,
    fontsize=28,
    color='red',
    ha='left',
    va='top'
)

plt.subplots_adjust(bottom=0.35)
plt.show()

# %% [markdown]
# <details>
# <summary>[説明文]</summary>
# 上のグラフをみてください。グラフの横軸は質量ですが、グラフそのものには質量が目盛ってあるわけではなく、数が目盛ってあります。質量を数に変換するためには、単位質量で割る必要があります。すなわち、横軸は質量ではなく、質量を1kgで割った数が目盛ってあるのです。質量を表す量記号は、mと約束されています。mはkgの単位をもっています。横軸に質量、m/kgと書いてあるのは、mをkgで割って数とした測定量を目盛っているという意味になります。

# %% [markdown]
# ***
#
# ### 物理量の加成性
#
# *   $\underbrace{1\  \text{m} + 3\  \text{cm}}=1.03\  \text{m}$
# 同一次元
# *   $\underbrace{1\  \text{m} + 3\  \text{kg}}=???$
# 異次元

# %% [markdown]
# <details>
# <summary>[説明文]</summary>
# これも当然ですが、単位の異なる物理量に加成性はありません。1 mと3 cmは一見単位が異なるようにもみえますが、同じ物理量ですから足すことは可能です。1 mと5kgを足すことができないのは当たり前ですね。
# それでは次に進みましょう。

# %% [markdown]
# ---
# ### 次元の一致 ###
#
# ~~~
# 物理量を表す数式では、すべての項の次元は等しくなければならない。
# ~~~
#
# * 次元一致例:ベルヌーイの定理（エネルギー保存則）
# $$
# \frac{1}{2}u^2+\frac{P}{\rho} + gZ = \text{constant}
# $$
# $$
# \begin{align*}
# u&: \text{流速} [\text{m}\ \text{s}^{-1}] \\
# P&: \text{圧力} [\text{Pa}=\text{kg}\ \text{m}^{-1}\ \text{s}^{-2}]\\
# \rho&: \text{密度}\  [\text{kg}\ \text{m}^{-3}]\\
# g&:\text{重力加速度} \\
# Z&: \text{高さ}\  [\text{m}]\\
# \end{align*}
# $$

# %% [markdown]
# <details>
# <summary>[説明文]</summary>
# 先ほど単位の異なる物理量に加成性は成り立たないと言いました。
# ここに例示したベルヌーイの定理の式、これは流体の持つエネルギーが流速と圧力および位置エネルギーの３つの項で表され、その総和は一定であることを示す式ですが、３つの項の単位は、すべてm2/s2でそろっています。
# したがって、３つの項には加成性が成り立ちます。

# %% [markdown]
# ---
# *   これはどうでしょう？（実験式等）
# $$
# C_p=28.11 + 0.197 \times 10^{-2} T+0.48 \times 10^{-5} T^2 -1.97 \times 10^{-9} T^3
# $$

# %% [markdown]
# <details>
# <summary>[説明文]</summary>
#
# $T$ の次元は [$\mathrm{K}$]
# $T^2$ の次元は [$\mathrm{K}^2$]
# $T^3$ の次元は [$\mathrm{K}^3$]
#
# です。
#
# 加算される項はすべて同じ次元でなければならないので、
#
# $0.197\times10^{-2}$
#
# は実際には
#
# $0.197\times10^{-2} \frac{[C_p]}{\mathrm{K}}$
#
# という次元を持っています。と考えてください。
#
# 同様に
#
# $0.48\times10^{-5}$
# は
#
# $0.48\times10^{-5} \frac{[C_p]}{\mathrm{K}^2}$
#
# という次元を持っています。
#
# つまり、実験式には、単位的に理解しかねるものが多いですが、
#
# 「係数を無次元数とみなすと各項の次元が一致しない」
#
# あるいは
#
# 「係数ごとに異なる単位を持たせて無理やり合わせている経験式」
# と考えてください。

# %% [markdown]
# ---
# <h1>基本単位(SI単位）</h1>
#
# |物理量|物理量（英語）|名称|記号|
# |---|---|---|---|
# |長さ|length|meter|$l$ [m]|
# |質量|mass|kilogram|$m$ [kg]|
# |時間|time|second|$t$ [s]|
# |電流| current|ampere| $I$ [A]|
# |温度|temperature|Kelvin| $T$ [K]|
# |物質量| Amount of substance| mole| $n$ [mol]|
# |光度| luminous intensity| candela| $I, Iv$ [cd]|
# |平面角 |plane angle| radian| [rad]|
# |立体角 |solid angle| steradian| [sr]|

# %% [markdown]
# <details>
# <summary>説明文</summary>
# 国際的に定められた物理量の基本単位群を国際単位系といい、それらの単位はSI単位と呼ばれます。SI単位はわずか7種類の基本単位から構成されています。
# すなわち長さ、質量、時間、電流、温度、物質量、光度です。
# それらには厳格な定義と記号が定められています。例えば長さの単位はメートル、その量記号はlと決められています。ちなみに量記号はイタリックで表示することが約束です。
# 私たちが化学でよく使用する物質量も、7つの基本単位のひとつで、その量記号はnとなっています。
# それでは次に進んでください。

# %% [markdown]
# ---
# <h1>組立単位(固有の名称をもつ例）</h1>
#
# |物理量|物理量（英語）|固有の名称|記号|SI単位による表現|
# |---|---|---|---|---|
# |周波数 |frequency |Hertz| $f$ [Hz]| 1/s|
# |力 |force| Newton| $F$ [N]| kg m s$^{-2}$|
# |圧力| pressure| Pascal| $p$ [Pa]| N m$^{-2}$ = kg m$^{-1}$ s$^{-2}$|
# |エネルギー| energy| Joule| $E$ [J] |N m = kg m$^2$ s$^{-2}$|
# |仕事率| |Watt| $P$ [W] |J s$^{-1}$= kg m$^2$ s$^{-3}$|
# |電気量| Amount of electricity| Coulomb| $Q$ [C]| A s|
# 電圧 |voltage |Volt| $V$ [V] |W A$^{-1}$|
# |静電気量 |Amount of static electricity| Farad |$C$ [F] |C V$^{-1}$|
# |電気抵抗| resistance |ohm| $R$ [Ω] |W A$^{-2}$|

# %% [markdown]
# <details>
# <summary>説明文</summary>
# 基本単位は７つしかありませんが、私たちが扱う物理量はもっと沢山あります。例えば力では1kgの物体に1m/s2の加速度を生じさせるとき、その力を1 Nと定義しています。しかしこれはkgとmとsがあれば、kg m s-2と組み立てる事が可能です。したがって、これらの単位は組立単位と呼ばれます。しかし、力をいつもkg m s-2と表すのは煩わしいですね。そこでNという単位が用いられているわけです。同様に圧力は1m2あたりに1Nの力がかけられているとき、1 Paと定義されます。しかし、1 Paもkg m-1 s-2と組み立てることが可能です。
# 仕事は力×距離ですから、N mすなわちkg m2 s-2となります。これはJに置き換えられています。
# その他は省略して次に進みましょう。

# %% [markdown]
# ---
# <h1>組立単位(固有の名称を持たない例）</h1>
#
# |物理量|物理量（英語）|名称|記号|SI単位による表現|
# |---|---|---|---|---|
# |物理量|物理量（英語）|名称|記号|SI単位による表現|
# |面積|area|square meter|$A$, (S)|m$^2$|
# |体積|volume|cubic meter, solid meter|$V$ |m$^3$|
# |速さ|velocity|meter per second|$v$|m s$^{-1}$|
# |加速度|acceleration|meter per square second|$a$|m s$^{-2}$|
# |密度|density|kilogram per cubic meter|$\rho$|kg m$^{-3}$|
# |熱容量|heat capacity|Joule per Kelvin|$C$|J K$^{-1}$|
# |粘度|viscosity|Pascal second|$\eta$, $\mu$|Pa s|
# |モル濃度|molality|mole per cubic meter|$c$|mol m$^{-3}$|

# %% [markdown]
# <details>
# <summary>説明文</summary>
# 先ほどの単位は名称と固有の単位とをもつものでしたが、固有の単位をもたない物理量も少なくありません。
# 面積は実は多くの固有名称をもつ単位が世界中に存在しますが、物理の世界ではm2で表します。m2で表すにはあまりにも小さい、あるいは大きい面積は、このあと述べる接頭語をつけて表現します。
# 確認したら次に進んでください。

# %% [markdown]
# ***
# ## 単位の換算 ##

# %% [markdown]
# <figure style="text-align:center;">
# <img
# src="https://raw.githubusercontent.com/myokota812/lecture/master/ChE1/figures/unitconversion.png"
# width="600">
# <figcaption>
# 図3 単位の換算概略図
# </figcaption>
# </figure>

# %% [markdown]
# ---
#
#
# $12X=10Y$
# $1X=(10/12)Y$
#
# 例
#
#
# *   atmからkPa
# 1 atm = 101.325 kPa
# $x$ atm = 101.325$x$ kPa
# *   calからJ
# 1 cal =4.1868 J
# $x$ cal = 4.1868$x$

# %% [markdown]
# <details>
# # <summary>説明文（"「▶説明文」のところをクリックすると表示されます）</summary>
# 単位の換算は、要は慣れですが、時々混乱することがあります。いまXという単位系ではある物理量が12Xと表され、Yという単位系では同じ物理量が10Yであるとします。
# そうすると12X=10Yということになります。XからYに単位を換算したいときは、1Xが何Yかということが必要になります。この例では、1Xは(10/12)Yです。従ってaXという物理量はa(10/12)Yということになります。
# 例えば、1 atm=101.325 kPaという関係が与えられているとき、atmからkPaに直したければ、1 atmは何kPaを知る必要があります。同様に、calからJに換算したければ、1calが何ジュールかを知る必要があります。
# これで混乱しない人は問題ありません。次に進みましょう。

# %% [markdown]
# ---
# ## 単位換算の妙法 ##
#
#
# 1.   与えられた換算関係を分数にする
# （そのとき、換算前の単位を分母にする）
# 2.   その分数を換算前の物理量にかける
#
# ### 例1: 圧力単位の換算 ###
#
# 1. 与えられた関係:  1 atm = 101.325 kPa
# 2. 必要な換算: atmからPa
# 3. 作るべき分数
# $$
# \frac{101.325\  \text{kPa}}{1\  \text{atm}}
# $$
#
# ~~~
#  20 atmをPaに換算しなさい。
# ~~~
# あえて段階的に記述します。
#
# Step1: $20\  \text{atm}$
#
# Step2:
# $$20\  \mathrm{~atm~} \times \frac{101.325 \text{kPa}}{1 \text{atm}}
# $$

# %% [markdown]
# <details>
# <summary>説明文（"「▶説明文」のところをクリックすると表示されます）</summary>
# 先の説明で、多少自信がない人は、次の換算方法を勧めます。というのは、都合よく換算元の量が１の単位としてばかり与えられていないことが少なくないからです。
# 換算したい単位同士に、ある等式があれば、それだけで十分です。その等式から、分数をつくります。両辺は等しいのですから、左辺を右辺で割っても、右辺を左辺で割っても、等しい物理量どうしの商は必ず１になります。これは単位のない、数としての１です。
# 従って、ここでつくった分数は、どのような物理量にかけても、その物理量を変化させることはありません。分数をつくるときに、ひとつだけこつがあります。その後消したい単位を分母にもってくることです。
# 例えば、1 atm=101.325 kPaの関係から、1atm分の101.325 kPaは１となります。ここでつくった分数を20 atmにかけてみましょう。数字の１をかけているのですから、20 atmという物理量は変化しません。しかし、分母と分子に表れるatmは消えて、kPaになります。
# このようにして、任意の等式からつくった１に相当する分数をある物理量にかけることで、単位の換算を行うことができます。単位をつけたままで換算するので、間違う事がありません。
# 次に進みましょう。

# %% [markdown]
# ---
# ### 例2: エネルギー単位の換算 ###
#
# 1. 与えられた関係:  1 cal = 4.18 J
# 2. 必要な換算: calからJ
# 3. 作るべき分数
# $$
# \frac{4.18\  \text{J}}{1\  \text{cal}}
# $$
#
# ~~~
# 20 kcalをJに換算しなさい。
# ~~~
# あえて段階的に記述します。
#
# Step1: $20\  \text{kcal}$
#
# Step2:
# $$20\  \mathrm{kcal} \times \frac{4.18 \text{J}}{1 \text{cal}}=83.6\  \text{kJ}
# $$

# %% [markdown]
# ---
# ### 例3: 気体定数の換算 ###
#
# $R$=8.314 $\text{J}\cdot\text{K}^{-1} \text{mol}^{-1}$
# の単位を$\text{L}\cdot\text{atm}\cdot\text{K}^{-1} \cdot \text{mol}^{-1}$に変換する。
#
# まず$1 \text{J}=1 \text{Pa m}^3$ ですので、１$\text{J}$は何$\text{L} \cdot \text{atm}$
#
# か変換する方法で進めます。
#
# 1. 与えられた関係:  1 Pa =$9.869 \times 10^{-6} \text{atm}$および1 $\text{m}^3=1000 \text{L}$
# 2. 必要な換算: Paからatmおよびm$^3$からL
# 3. 作るべき分数
# $$
# \frac{9.869 \times 10^{-6} \text{atm}}{1 \text{Pa}}\ \&
# \frac{1000 \text{L}}{1 \text{m}^3}
# $$
#
# $R$=8.314 $\text{J}\cdot\text{K}^{-1} \text{mol}^{-1}$
# の単位を$\text{L}\cdot\text{atm}\cdot\text{K}^{-1} \cdot \text{mol}^{-1}$への変換は
#
# $$
# R=8.314\  \text{J}\cdot\text{K}^{-1} \text{mol}^{-1} =8.314\  \text{Pa}\cdot\ \text{m}^3 \cdot \text{K}^{-1} \text{mol}^{-1} \times \frac{9.869 \times 10^{-6} \text{atm}}{1 \text{Pa}} \times \frac{1000 \text{L}}{1 \text{m}^3}=0.08205 \text{L}\cdot\text{atm}\cdot\text{K}^{-1}
# $$

# %% [markdown]
# <details>
# <summary>説明文（"「▶説明文」のところをクリックすると表示されます）</summary>
# 与えられた関係が、1 cal=4.18 Jであれ、1J=0.239 calであれ、calからJに換算したいときは、calが分母に来るような分数をつくります。どちらも１を与えます。
# 20 kcalをJに変換したければ、今つくった分数のどちらでも、かければ自動的に単位が換算されます。
# 気体定数は多くの単位系で表されるため、初学者は混乱しやすいものです。私たちが高校生のとき化学では、気体定数を0.082 L atm/K molと習いました。大学に来ると突然8.314 J/K molとなり、戸惑ったものです。L atmのように体積と圧力の積がエネルギーを表すことがわかるまで私のこの混乱は解決されませんでした。体積をm3、圧力をPaに換算しておけば、Pa m3はJに等しいのです。これは先の組立単位をみて確認してください。
# それでは次に進みましょう。

# %% [markdown]
# <font color= "red">課題1</font>
#
#
# 1.   1ft =304.8 mmが与えられている場合、200 mmは何ftか。
# 2.   1 cal=4.18 Jが与えられている場合、100 kJは何kcalか。
# 3.   1 m$^3$ = 106 cm$^3$が与えられている場合、20 cm$^3$は何m$^3$か。
# 4.   1 L=10$^{-3}$ m$^3$, 1 atm=101325 Pa, 1J= 1 Pa m$^3$が与えられているとき、0.082 atm L K$^{-1}$ mol-1は何J K$^{-1}$ mol$^{-1}$か。

# %% [markdown]
# <font color= "red">回答はこちらに. </font>.
#
# (計算結果だけで結構です。?????のところを数値に変えてください。ダブルクリックするとtext入力モードになり、数値を記入することができます。????は消してください。単位は記入済みです。）
# 1. ???????? ft
# 2. ???????? kcal
# 3. ???????? $\mathrm{m}^3$
# 4. ???????? $\mathrm{J}\ \mathrm{K}^{-1}\mathrm{mol}^{-1}$
#
# <font color= "blue">さらに、下記の追加学習完了後、保存して提出してください。</font>

# %% [markdown]
# #追加学習
#
# 以降は海外の大学における教材です。単位換算の学習ですが、海外の大学の教育内容の一端を見てもらいたく、教材としました。海外では実に様々な単位が使われていることがわかると思います。将来的に、国際プロジェクト等にたずさわる機会があれば、相手が常用している単位系にこちらがあわせる必要が出る場合もうあるかもしれません。そのつもりで一通り目を通してください。pythonコードは実行して、何を計算しているのか程度は理解してください。

# %% [markdown]
# Licensed under CC-BY 4.0 - see further details at the CC website here or below: https://creativecommons.org/licenses/by/4.0/
#
# Creative Commons Attribution 4.0 International Public License

# %% [markdown]
# # 1.1 &ndash; Unit Conversions
#
# ---

# %% [markdown]
# ## 1.1.0 &ndash; Learning Objectives
#
# By the end of this section you should be able to:
#
# 1. Understand the importance of unit conversion.
# 2. Understand the concept of a conversion factor.
# 3. Convert a unit from one to the other.
#
#
# ---

# %% [markdown]
# ## 1.1.1 &ndash; Introduction
#
# Knowing how to **convert units** is vital to engineers. Improperly converted units could mean the difference between life and death. With Canada's proximity to the USA, it is very important to learn how to convert from imperial to metric and vise versa. It is also important to know how to convert from one unit to another in the same system such as $m^3$ to $l$.
#
# ---

# %% [markdown]
# ## 1.1.2 &ndash; Conversion Factors
#
# **Conversion factors** are ratios between two expressions of the same quantity. For an example:
#
# $$ \frac{1 cm}{10 mm} \quad \text{(1 centimeter per 10 millimeters)} $$
#
# or
#
# $$ \frac{1 kg^2}{1,000,000 g^2} \quad \text{(1 kilogram squared per 1,000,000 grams squared)} $$
#
# or
#
# $$ \frac{1 m^3}{1,000,000,000 m m^3} \quad \text{(1 cubic meter per 1,000,000,000 cubic millimeters)} $$
#
# ---

# %% [markdown]
# ## 1.1.3 &ndash; Converting Units
#
# To convert a quantity from one unit to its equivalent of another unit, we will use conversion factors. For example, if we want to convert 7.2 km to meters, we would write:
#
# $$ 7.2 km \times \frac{1,000 m}{1 km} = 7,200 m  $$
#
# As you can see, the original unit is km, the final unit is m, and the conversion factor is $\frac{1,000m}{1km}$.
#
# ---

# %% [markdown]
# ## 1.1.4 &ndash; Dimensional Homogeneity
#
# Consider the equation
#
# $$ u = u_0 + gt $$
#
# where the corrisponding units are
#
# $$ [m/s] = [m/s] + [m/s^2] \times [s] $$
#
# Now lets inputed values for each of the varibles in the first equation.
#
# $$ 45 \space \frac{m}{s} \neq 12 \space \frac{m}{s} + 9.81 \space \frac{m}{s^2} \cdot 3.36 \space min $$
#
# You may ask why $45 \neq 45$ and that is because the dimensions are not homogenous. The units are not consistent. The velocity and accelartation are measured in seconds, yet the time we used is minutes. To correct the formula, we must change the minutes to seconds.
#
# $$ 45 \space \frac{m}{s} \neq 12 \space \frac{m}{s} + 9.81 \space \frac{m}{s^2} \cdot 3.36 \space s $$
#
# ---

# %% [markdown]
# ## 1.1.5 &ndash; Problem Statement
#
# ### Problem 1
#
# #### Question
#
# Suppose the average house in Vancouver uses 342 gallons of water per day. How many $cm^3$ of water per second is used on average? What are your conversion factors?
#
# #### Answer

# %%
water_use = 342 # gallons/day

seconds_per_day = 86400 # s/day
litres_per_gallon = 3.78541 # l/gallon
cub_m_per_litre = 0.001 # m^3/l
cub_c_per_cub_m = 1000000 # cm^3/m^3

water_use_1 = water_use*litres_per_gallon*cub_m_per_litre*cub_c_per_cub_m/seconds_per_day

print("The average house uses",water_use_1,"cm^3/s")
# Out:
# The average house uses 14.983914583333332 cm^3/s

# %% [markdown]
# The conversion factors are:
# $$ \frac{86400s}{1 day}$$
#
# $$ \frac{3.78541 litre}{1 gallon}$$
#
# $$ \frac{0.001 m^3}{1 litre}$$
#
# $$ \frac{1,000,000 cm^3}{1 m^3}$$
#
# Written out, this would look like:
#
# $$  \frac{342 \space gallons }{1\space day} \cdot  \frac{1\space day}{86400s} \cdot \frac{3.78541 litre}{1 gallon} \cdot \frac{0.001 m^3}{1 litre} \cdot \frac{1,000,000 cm^3}{1 m^3} =  14.983914583 \frac { cm^3}{s}
# $$
#
# ### Problem 2
#
# #### Question
#
# Despite the odds, the Kinger-Sporgan pipeline is being built to no environmental impact, which will soon supply BC and Washington state with 40,001 barrels of oil biweekly (including weekends). As an employee of Dusty Oil in Vancouver, you keep in contact with your colleagues in the United States and update them on the amount of oil being supplied. Since they use metric and you use the imperial system, what is the amount of oil transported, in metric?
#
# **Note**: Use 1 oil barrel = 35 imperial gallons. Not US gallons.
#
# #### Answer
#
# According to the back of our text,
#
# $$1000 \space L = 220.83 \space \text{imperial gallons}$$
#
# Let's find out how many litres are in an imperial gallon first:
#
# $$ 1000 \space L \space \div \space 220.83 \space \text{imperial gallons} = 4.5283 \space \frac{L}{\text{imperial gallons}} $$
#
# Now we know that biweekly, the total amount of oil transported is:
#
# $$ 40,001 \space barrels \space \times \space 35 \space 35 \space \frac{\text{imperial gallons}}{barrels} \times \space 4.5283 \space \frac{L}{\text{imperial gallons}} = 6339778 \space litres $$
#
# Let's find how many litres are transported in seconds. Since I don't know how many seconds are in a fortnight off the top of my head:
#
# $$ 14 \space days \space \times \space 24 \space \frac{hours}{day} \space \times \space 3600 \space \frac{seconds}{hour} = 1209600 \space seconds $$
#
# Finally, you can report that the total amount of oil transported, in metric units, is:
#
# $$ 6339778 \space litres \div 1209600 \space seconds = 5.241 \space \frac{L}{s} $$

# %% [markdown]
# <!--NAVIGATION-->
# < [Units, Quantities, and Engineering Calculations](http://nbviewer.jupyter.org/github/jckantor/CBE20255/blob/master/notebooks/01.00-Units-Quantities-and-Engineering-Calculations.ipynb) | [Contents](toc.ipynb) | [Units and Conversions for Home Heating](http://nbviewer.jupyter.org/github/jckantor/CBE20255/blob/master/notebooks/01.02-Units-and-Conversions-for-Home-Heating.ipynb) ><p><a href="https://colab.research.google.com/github/jckantor/CBE20255/blob/master/notebooks/01.01-Units-and-Engineering-Calculations.ipynb"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open in Google Colaboratory"></a>

# %% [markdown]
# # Units and Engineering Calculations

# %% [markdown]
# ## Summary
#
# The purpose of this [Jupyter notebook](http://jupyter.org/notebook.html) is to get you started with units and engineering calculations.
#
# Things to master:
#
# * Unit systems
# * Unit conversions
# * Difference between mass and weight, and the difference between kg-m, kg-f, and lbm and lbf
# * Concept of mole, and the difference between g-mol, kg-mol, and any other kind of mole
# * Absolute versus Gauge Pressure
# * Typical values of temperature and pressure in real-world applications
# * Working with units in python using the `pint` library.

# %% [markdown]
# <font color="red">課題2</font>
# pythonの pint ライブラリーで何ができるか。以下にタイプして回答してください。
#
# 記入はここから

# %% [markdown]
# ## Units of Engineering

# %% [markdown]
# ### The Fundamental Units of Measurement
#
# There are seven fundamental units in the Système International d'Unités (SI) system, all other unit can be generated from these.
#
# | Dimension          | SI Units          | CGS                 | English              |
# | :-------           | :---              | :-----              | :------              |
# | Mass               | kilogram (kg)     | gram (g)            | lb-mass, slug        |
# | Length             | meter (m)         | centimeter (cm)     | inch (in); foot (ft) |
# | Time               | second (s)        | second (s)          | second (sec)         |
# | Temperature        | degree Kelvin (K) | degree Celsius (°C) | degree Rankine (°R)  |
# | Quantity           | mole (gmol)       | mole (gmol)         | mole (gmol)          |
# | Current            | Ampere (A)        | abampere            |                      |
# | Luminous Intensity | candela (cd)      | stlib [luminance]   | candlepower, etc.    |

# %% [markdown]
# > **Exercise.** Give an everyday example of something with about 1 SI unit of the corresonding dimension.

# %% [markdown]
# ### Coherent Derived Units
#
# The SI system describes 22 'derived units' that are expressed in terms of the fundamental units. The following diagram from [NIST illustrates the relationship among the SI units](http://physics.nist.gov/cuu/Units/SIdiagram.html).
#
# ![](http://physics.nist.gov/cuu/Units/i/SubwayDiagram.gif)
#
# Calculations with coherent units is straightforward since they involve just ratios or products of base units. The calculations break down into three steps:
#
# 1. Recast all of the problem quantities in base or coherent derived units.
# 2. Perform the numerical calculations.
# 3. Using algebraic rules for the cancelation of terms, simplify and reduce units to units relevant to the context of the problem.

# %% [markdown]
# >**Example:** The kinetic energy of a object with mass $m = 3\ \mbox{kg}$ traveling at velocity $v = 10 \ \mbox{m/s}$ is given by
# >
# >\begin{align*}
# K.E. & = \frac{1}{2} mv^2 \\
# & = \frac{1}{2} \left(3\ \mbox{kg}\right)\left( 10  \frac{\mbox{m}}{\mbox{s}}\right)^2 \\
# & = 150 \ \frac{\mbox{kg}\cdot\mbox{m}^2}{\mbox{s}^2}
# = 150 \ \mbox{N}\cdot\mbox{m}
# = \fbox{150 J}
# \end{align*}

# %% [markdown]
# > **Example:** What is the mass of air in a spherical balloon with radius of 10 cm inflated to 1 atm at 25 degrees Celsius? Assume the molecular weight of air is 28.966 grams/mole, and that atmospheric pressure is 101,325 Pa.
# >
# > _Solution:_ Start by converting all of the quantities in the problem to base or derived units.
# >
# > $$MW_{air} = 28.966\ \frac{\mbox{g}}{\mbox{mol}} = 0.028966\ \frac{\mbox{kg}}{\mbox{mol}}$$
# >
# > $$ P = 101,325\ \mbox{Pa} = 101,325\ \frac{\mbox{N}}{\mbox{m}^2} = 101,325\ \frac{\mbox{kg}}{\mbox{m}\cdot\mbox{s}^2}$$
# >
# > $$V = \frac{4}{3}\pi r^3 = \frac{4}{3}\pi \left( 0.10\ \mbox{m}\right)^3 = 0.004189\ \mbox{m}^3$$
# >
# > $$R = 8.314 \frac{\mbox{J}}{\mbox{K}\cdot\mbox{mol}} = 8.314 \frac{\mbox{kg}\cdot\mbox{m}^2}{\mbox{s}^2\cdot\mbox{K}\cdot\mbox{mol}}$$
# >
# > $$T = 25 + 273.15 = 298.15 K$$
# >
# > Using molecular weight and the ideal gas law
# >
# > $$ m_{air} = MW_{air} n_{air} = MW_{air}\frac{PV}{RT} $$
# >
# > Substituting quantities into this expression for $m_{air}$
# >
# > \begin{align*}
#  m_{air} & = \left(0.028966\ \frac{\mbox{kg}}{\mbox{mol}}\right)
#  \frac{\left(101,325\ \frac{\mbox{kg}}{\mbox{m}\cdot\mbox{s}^2}\right)\left(0.004189\ \mbox{m}^3\right)}{\left(8.314 \frac{\mbox{kg}\cdot\mbox{m}^2}{\mbox{s}^2\cdot\mbox{K}\cdot\mbox{mol}}\right)\left(298.15\ \mbox{K}\right)} \\
#  & = \frac{0.028966 \cdot 101,325 \cdot 0.004189}{8.314 \cdot 298.15} \times \frac{\frac{\mbox{kg}}{\mbox{mol}}\cdot\frac{\mbox{kg}}{\mbox{m}\cdot\mbox{s}^2}\cdot\mbox{m}^3}{\frac{\mbox{kg}\cdot\mbox{m}^2}{\mbox{s}^2\cdot\mbox{K}\cdot\mbox{mol}} \cdot \mbox{K}}\\
#  & = \fbox{0.00496 kg}
#  \end{align*}

# %% [markdown]
# ### Non-Coherent  Derived Units
#
# Coherent units are easy to work with because no numerical factors are required to express them in terms of the base units. On the other hand, working with such a limited set of units makes it difficult to express commonly quantities in easy-to-remember numbers or do back-of-the-envelop calculations. Having to write a multiple of 101,325 Pa to express commonly encountered pressures is just asking for computational errors.
#
# Non-coherent derived units are quantities that can be expressed in terms of a numerical factor and product or ratio of base units. Here are some common examples:

# %% [markdown]
# ## Absolute versus Offset Scales
#
# For the purpose of applying the ideal gas law, what is the air pressure in this tire?
#
# ![Tire_pressure_gauge.jpg](https://raw.githubusercontent.com/jckantor/CBE20255/master/notebooks/figures/Tire_pressure_gauge.jpg)
#
# The quantities used in most scientific calculations are measured on absolute scales, such as mass and length. On a absolute scale, a value of zero implies the absence of the underlying quantity. Something with zero mass has no mass, something with zero length means it has no length.
#
# Some common engineering measurements, however, are reported 'relative to' or 'offset from' a reference value.  For example, degrees Celsius measures temperature relative to the melting point of ice; degrees Fahrenheit measures temperature relative to a brisk winter day. In the figure above, tire pressure is being measured relative to pressure of the surrounding air.  This is called the 'gauge pressure' because that is what is being measured by the pressure gauge.
#
# The offsets result in numerical values convenient for common everyday use, but introduce an additional consideration (and source of errors!) for engineering calculations.
#
# Examples of offset scales include:
#
# * Degrees Celsius
# * Degrees Fahrenheit
# * Gauge Pressure (pressure relative to normal atmospheric pressure).
# * Enthalpy and Free Energy of Formation (energy required to form a substance relative to standard laboratory conditions.)
# * Calendar dates (days relative to start of the Common Era)
#
# Engineers sometimes distinguish absolute and gauge pressures by adding an explicit suffix. In particular, psia refers to 'pounds per square inch absolute', while psig refers to 'pounds per square inch gauge'. Non-engineers almost never make these distinction, so you need to be very careful when interpreting information given to you! It's always your responsibility to resolve any ambiguity in the data given to you for analysis.
#
# The misuse of pressure and temperature scales is a common source of errors in engineering calculations.

# %% [markdown]
# > **Example:** A football is inflated to 12.5 psig (pounds per square in gauge) at
# > 70 degrees F. The football is taken to play outdoors at 40 degrees F. Using the
# > gas law,
# >
# > $$P_2/T_2 = P_1/T_1$$
# >
# > what is the pressure of the football at playing conditions?
# >
# > _Solution:_ The ideal gas law assumes quantities are given in absolute units.
# > The problem statement, however, gives conditions in offset units. In this case,
# > 0 degrees Farhenheit is 459.67 in absolute (Rankine) units, and 0 psig is
# > 14.696 psia in absolute units. Incorporating the offsets the gas law reads
# >
# > $$\frac{P_2 + 14.696}{40 + 459.67} = \frac{12.5 +  14.696}{70 + 459.67}$$
# >
# > Solving for $P_2$
# >
# > $$P_2 = \frac{40+459.67}{70+459.67}(12.5 + 14.696) - 14.696 = 10.96\ \mbox{psig}$$

# %% [markdown]
# ## Extensive versus Intensive Quantities
#
# An important distinction among measured quantities arises when we consider what happens when combining systems under consideration. For example, mixing two identical one-liter containers of an acidic solution yields two liters of the solution, twice the mass of solution, and twice the number of molecules of all types. If the solutions were at a high  temperature, the result would have twice the thermal energy content. Quantities that _scale_ in direct proportion to the size of sytem are _extensive_ quantities.
#
# Other quantities, such as the temperature of the mixture, concentration of acid in the mixture, or vapor pressure are independent of the size of a system. Quantities that do not scale with the size are _intensive_ quantities.
#
# This distinction is fundamental to process modeling and thermodynamics.

# %% [markdown]
# > **Exercise.** Catagorize the following quantities as either extensive or intensive variables: Concentration, density, electrical charge, electrical resistivity, length, material hardness, mass, moles, pH, pressure, specific volume, temperature, viscosity, volume.

# %% [markdown]
# ## Ideal Gas Law Calculations
#
# The ideal gas law is a work horse of engineering calculations.
#
# \begin{equation}
# PV = nRT
# \end{equation}
#
# Despite its simplicity and familiarity, misuse of units and scale for pressure $P$ and temperature $T$, and identifying correct values of the gas constant $R$, are common sources of errors in homework and exams. Taking time now to really master ideal gas law calculations will pay dividends down the road.

# %% [markdown]
# ### Absolute Temperature
#
# | Reference | F | C | R | K |
# | :- | :-: | :-:  | :-:  | :-: |
# | Absolute Zero | -459.67 | -273.15 | 0 | 0 |
# | Normal Boiling point of $N_2$ | |
# | Dry Ice | -109.3 | -78.5 | | |
# | Boiling Point of Propane | -43.6 | -42 | | |
# | Freezing Point of Water | 32 | 0 | 491.67 | 273.15 |
# | STP | | | | |
# | Typical Room Temperature | 68 | 20 | | |
# | Pleasant Summer Day | 77 | 25 | | |
# | Human Body | | 37 | | |
# | Normal Boiling Point of Water | 212 | 100 | | |
# | 10 psig steam |  |  | | |
# | 70 psig steam | | |  |
# | 400 psig steam | | | |

# %% [markdown]
# ### Absolute versus Gauge Pressure
#
# Every engineer needs to know atmospheric pressure in common engineering and scientific units. If need to look up these numbers then you're doing it wrong.
#
# | Value | Unit |
# | :---: | :--: |
# | 1 | atm |
# | 14.696 | pounds per square inch (absolute), psia |
# | 0 | pounds per square inch (gauge), psig |
# | 101,325 | Newtons per square meter (Pascals) |
# | 101.325 | kiloPascals |
# | 1.01325 | bars |
# | 1013.25 | millibars |
# | 760 | mm Hg |
# | 760 | torr |
# | 29.92 | in Hg
# | 33.9 | feet of water |

# %% [markdown]
# ## Working with Units in Python using the pint library
#
# There are a number of python libraries that incorporate units into python calculations. Among these, [pint](http://pint.readthedocs.org/en/latest/) is a relatively new library that builds on experience with earlier attempts.

# %%
#この欄はコード入力欄です。本講義ではPythonを使います。
#本日の講義ではプログラムは入力済みですので、左の▶︎をクリックして実行してください。
# !pip install pint

# %% [markdown]
# The core concept in pint is to work with a `unit registry`, which is created as follows

# %%
from pint import UnitRegistry
ur = UnitRegistry()

# %% [markdown]
# ### Assigning Multiplicative Units
#
# The unit registry provides a simple means to assign units using the multiplication operator. For example, here's how to compute the molarity of a sodium chloride solution in 58.44 grams of $NaCl$ (mw = 58.44) has been dissolved in water to form 3 liters of solution.

# %%
#ここも実行するだけで結構です。何を計算しているのかは理解してください。
# problem data
V = 3.0 * ur.liters
m = 58.44 * ur.grams
mw = 58.44 * ur.grams/ur.mol

# compute molarity
C = m/(mw*V)

print(C)

# %% [markdown]
# ### Unit Conversion
#
# Each variable with units has `to()` and `ito()` methods for converting the quantity to a desired set of units. The `to()` method is used to create a new variable by converting an existing variable to the indicated units.

# %%
x = 0.5 * ur.kilograms/ur.gallon
y = x.to(ur.grams/ur.liter)

print(x)
print(y)

# %% [markdown]
# The `ito()` method converts an existing variable 'in-place'.

# %%
x = 0.5 * ur.kilograms/ur.gallon
x.ito(ur.grams/ur.liter)

print(x)

# %% [markdown]
# For example, here's how to compute the molarity of a sodium chloride solution in which 0.5 pounds of NaCl (mw = 58.44) has been dissolved in water to form 2 gallons of solution.

# %%
# problem data
V = 3.0 * ur.gallons
m = 0.5 * ur.lbs
mw = 58.44 * ur.grams/ur.mol

# compute concentration
C = m/(mw*V)
print(C)

# convert to desired units and print
C = C.to(ur.mol/ur.liter)
print(C)

# convert to moles per gallon
C.ito(ur.mol/ur.gallon)
print(C)

# %% [markdown]
# Muratic Acid is concentrated hydrochloric acid (31.5% by weight) sold by the gallon in home improvement centers for cleaning brick and masonary surfaces. The density of the solution is typically about 1.15 grams/ml. What is the molar concentration of HCl?

# %%
# molecular weight
mwHCl = 36.46 * ur.grams/ur.mol

# problem data
rho = 1.15 * ur.grams/ur.ml
wHCl = 0.315 * ur.grams/ur.gram

# calculations
massHCl = wHCl * rho             # mass of HCl per volume
moleHCl = massHCl/mwHCl          # gmols of HCl per volume

print(moleHCl)

# convert to desired units
moleHCl.ito(ur.mol/ur.liter)
print(moleHCl)

# %% [markdown]
# ### Mole and Mass Fractions

# %%
# molar weights
mwBen = 78.11 * ur.grams/ur.liter
mwTol = 92.14 * ur.grams/ur.liter

xBen = 0.4 * ur.mol/ur.mol
xTol = 0.6 * ur.mol/ur.mol

wBen = mwBen*xBen / (mwBen*xBen + mwTol*xTol)

print(wBen)

# %% [markdown]
# ### Prefixes

# %%
mwBen = 78.11 * ur.kg/ur.kmol
print(mwBen)

mwBen.ito_base_units()
print(mwBen)

# %% [markdown]
# ### Temperature and Other Offset (Non-multiplicative) Units
#
# Examples of non-multiplicative units are degrees Celsius, degrees Fahrenheit, and gauge pressure. For these units the zero of the measurement scale is offset from absolute zero of the underlying physical quantity. In these cases the units are assigned using the `Quantity()` function of the `UnitRegistry` module.

# %%
T = ur.Quantity(25,ur.degC)

print(T, " = ", T.to(ur.degF))

# %% [markdown]
# There is an embedded ambiguity in working with non-multiplicative units. For example, given temperatures Ta = 10 and Tdelta = 25 in degrees C, should Ta + Tdelta give an answer of 35 degrees C, or the sum of the absolute temperatures which would correspond to 308.15 degrees C?
#
# Pint uses unit type called `delta_degC` for this situation.

# %%
Ta = ur.Quantity(10.0, ur.degC)
Tdelta = 25.0 * ur.delta_degC

print(Ta + Tdelta)

# %%
Tb = ur.Quantity(100.0, ur.degC)
Tf = ur.Quantity(32.0, ur.degF)

print("{0:6.3f}".format(Tb-Tf))
print("{0:6.3f}".format((Tb-Tf).to(ur.delta_degF)))

# %%
P1 = (12.5 + 14.696) * ur.psi

T1 = ur.Quantity(70, ur.degF).to(ur.degR)
T2 = ur.Quantity(40, ur.degF).to(ur.degR)

P2 = (T2/T1)*P1 - 14.696 * ur.psi
P2

# %%
import math
pi = math.pi

# constants
R = 8.314 * ur.joule/(ur.mol*ur.degK)
mw = 28.966 * ur.grams/ur.mol

# problem data
P = 1.0 * ur.atm
T = ur.Quantity(25,ur.degC).to(ur.degK)
r = 10 * ur.cm

# calculations
V = (4.0/3.0)*pi*r**3
print("Volume = ", V)

m = mw*P*V/(R*T)

print("Mass of Air = ", m.to(ur.grams))

# %% [markdown]
# <!--NAVIGATION-->
# < [Units, Quantities, and Engineering Calculations](http://nbviewer.jupyter.org/github/jckantor/CBE20255/blob/master/notebooks/01.00-Units-Quantities-and-Engineering-Calculations.ipynb) | [Contents](toc.ipynb) | [Units and Conversions for Home Heating](http://nbviewer.jupyter.org/github/jckantor/CBE20255/blob/master/notebooks/01.02-Units-and-Conversions-for-Home-Heating.ipynb) ><p><a href="https://colab.research.google.com/github/jckantor/CBE20255/blob/master/notebooks/01.01-Units-and-Engineering-Calculations.ipynb"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open in Google Colaboratory"></a>

# %% [markdown]
# 以上で終わりです。保存してWebClassに提出してください。
